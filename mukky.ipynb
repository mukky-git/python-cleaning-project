# %%
print(45+2)
# Out:
# 47

# %%
import pandas as pd

# %%
df = pd.read_csv("sales.csv")

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28
# 4       2025-08-11

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28
# 4       2025-08-11

# %%
df.info
# Out:
# <bound method DataFrame.info of    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28
# 4       2025-08-11  >

# %%
df.isna()
# Out:
#    CustomerID  FirstName  LastName  Country  Gender    Age  TotalPurchase  \
# 0       False      False     False    False   False  False          False
# 1       False      False     False    False   False  False          False
# 2       False      False     False    False   False  False          False
# 3       False      False     False    False   False  False          False
# 4       False      False     False    False   False  False          False
#
#    LastPurchaseDate
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
df.isna().sum()
# Out:
# CustomerID          0
# FirstName           0
# LastName            0
# Country             0
# Gender              0
# Age                 0
# TotalPurchase       0
# LastPurchaseDate    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# ##summary statistics: mean ,median,maximum,minimum

# %%
df.describe()
# Out:
#        CustomerID        Age  TotalPurchase
# count    5.000000   5.000000       5.000000
# mean     3.000000  32.800000     553.370000
# std      1.581139   5.495453     292.438125
# min      1.000000  27.000000     295.400000
# 25%      2.000000  29.000000     380.000000
# 50%      3.000000  32.000000     420.500000
# 75%      4.000000  35.000000     650.200000
# max      5.000000  41.000000    1020.750000

# %%
df.describe(include="object")
# Out:
#        FirstName LastName  Country Gender LastPurchaseDate
# count          5        5        5      5                5
# unique         5        5        3      2                5
# top        James    Okoro  Nigeria   Male       2025-10-15
# freq           1        1        2      3                1

# %%
import numpy as np

# %%
df.describe(exclude=[np.number])
# Out:
#        FirstName LastName  Country Gender LastPurchaseDate
# count          5        5        5      5                5
# unique         5        5        3      2                5
# top        James    Okoro  Nigeria   Male       2025-10-15
# freq           1        1        2      3                1

# %% [markdown]
# COLUM SELECTION

# %%
df.FirstName
# Out:
# 0     James
# 1       Ada
# 2      John
# 3      Mary
# 4    Samuel
# Name: FirstName, dtype: object

# %%
df["FirstName"]
# Out:
# 0     James
# 1       Ada
# 2      John
# 3      Mary
# 4    Samuel
# Name: FirstName, dtype: object

# %%
df[["FirstName", "LastName"]]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh
# 2      John      Doe
# 3      Mary  Adeyemi
# 4    Samuel   Mutiso

# %%
df[["FirstName", "LastName", "Age"]]
# Out:
#   FirstName LastName  Age
# 0     James    Okoro   32
# 1       Ada     Umeh   27
# 2      John      Doe   41
# 3      Mary  Adeyemi   35
# 4    Samuel   Mutiso   29

# %%
##loc , iloc
## df.loc[row, col]

df.loc[0:2,["FirstName" , "LastName"]]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh
# 2      John      Doe

# %%
df.loc[0:2 , :]
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01

# %%
df.iloc[0:2 , [1 ,2]]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh

# %%
df.iloc [0:2, 1:3]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh

# %%
df.iloc [0:3, 1:3]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh
# 2      John      Doe

# %% [markdown]
# DATA FILTERING

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %%
import numpy as np
