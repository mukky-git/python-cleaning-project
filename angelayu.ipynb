# %%
##this code would make us input our name and age using the input function 
## with this way anytime i call out the age column it gives me what ever i assigned it to 
name = input("What is your name? ")
age = input("How old are you? ")
print("Hello " + name + "," "\n" "you are " + age + " years old.")
lenght = len(name , age )
print(lenght)
# Out:
# Hello mukram,
# you are 50 years old.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 6
#       4 age = input("How old are you? ")
#       5 print("Hello " + name + "," "\n" "you are " + age + " years old.")
# ----> 6 lenght = len(name , age )
#       7 print(lenght)
#
# TypeError: len() takes exactly one argument (2 given)

# %%
##variable this u assign a variable it is also a name that stores value 
print(name)
# Out:
# mukram

# %%
##finding the length of a string 
name = "mukram"
print (len(name))
# Out:
# 6

# %%
city =input("name of city ")
pet =input("input pet name ")
print("your band name could be "+city + pet )
# Out:
# your band name could be lagos jack

# %%
##this code would make us input our name and age using the input function 
## with this way anytime i call out the age column it gives me what ever i assigned it to 
name = input("What is your name? ")
age = input("How old are you? ")
print("Hello " + name + "," "\n" "you are " + age + " years old.")
lenght = len(name )
print(lenght)

# %%
## this is a way off calling a text from a letter  it is also called subscripting
print("hello"[3])
# Out:
# l

# %%
print(12 +3)
# Out:
# 15

# %%
age = int(input("How old are you? "))
print(age + 5)
# Out:
# 5

# %%
##Here we were able to convert a integer to a string 
print("number of letters in your name " + str(len(input(" what is your name "))))
# Out:
# number of letters in your name 6

# %%
## using bmi caculator to caculate our weight and height 
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = weight // (height ** 2)

print("Your BMI is:", bmi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 7
#       3 height = float(input("Enter your height in meters: "))
#       5 bmi = weight // (height ** 2)
# ----> 7 print(round("Your BMI is:", bmi))
#
# TypeError: type str doesn't define __round__ method

# %%
#this is how you round up numbers
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = weight / (height ** 2)

print("Your BMI is:", round(bmi, 2))
# Out:
# Your BMI is: 0.0

# %%
print(6 + 4 / 2 - (1 * 2))
# Out:
# 6.0
