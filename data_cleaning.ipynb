# %%
import pandas as pd

# %%
# Pndas support all kinds of file reading
df = pd.read_csv("sales.csv", delimiter=",")

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate  Quantity    Sales      Order Group
# 0       2025-10-15         3  1261.50   Multiple Order
# 1       2025-09-23         4  1520.00   Multiple Order
# 2       2025-11-01         1  1020.75  Single Quantity
# 3       2025-10-28         5  3251.00   Multiple Order
# 4       2025-08-11         6  1772.40   Multiple Order

# %%
## Data Inspection
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        5 non-null      int64
#  1   FirstName         5 non-null      object
#  2   LastName          5 non-null      object
#  3   Country           5 non-null      object
#  4   Gender            5 non-null      object
#  5   Age               5 non-null      int64
#  6   TotalPurchase     5 non-null      float64
#  7   LastPurchaseDate  5 non-null      object
#  8   Quantity          5 non-null      int64
#  9   Sales             5 non-null      float64
#  10  Order Group       5 non-null      object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 572.0+ bytes

# %%
df.shape
# Out:
# (5, 11)

# %%
df.describe() # Numerical Columns
# Out:
#        CustomerID        Age  TotalPurchase  Quantity        Sales
# count    5.000000   5.000000       5.000000  5.000000     5.000000
# mean     3.000000  32.800000     553.370000  3.800000  1765.130000
# std      1.581139   5.495453     292.438125  1.923538   876.883115
# min      1.000000  27.000000     295.400000  1.000000  1020.750000
# 25%      2.000000  29.000000     380.000000  3.000000  1261.500000
# 50%      3.000000  32.000000     420.500000  4.000000  1520.000000
# 75%      4.000000  35.000000     650.200000  5.000000  1772.400000
# max      5.000000  41.000000    1020.750000  6.000000  3251.000000

# %%
df['CustomerID']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: CustomerID, dtype: int64

# %%
df.CustomerID
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: CustomerID, dtype: int64

# %%
df[['Age', 'TotalPurchase']].describe()
# Out:
#              Age  TotalPurchase
# count   5.000000       5.000000
# mean   32.800000     553.370000
# std     5.495453     292.438125
# min    27.000000     295.400000
# 25%    29.000000     380.000000
# 50%    32.000000     420.500000
# 75%    35.000000     650.200000
# max    41.000000    1020.750000

# %%
df.describe(include="object")
# Out:
#        FirstName LastName  Country Gender LastPurchaseDate     Order Group
# count          5        5        5      5                5               5
# unique         5        5        3      2                5               2
# top        James    Okoro  Nigeria   Male       2025-10-15  Multiple Order
# freq           1        1        2      3                1               4

# %%
import pandas as pd

# %%
df = pd.read_csv("sales.csv")

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate  Quantity    Sales      Order Group
# 0       2025-10-15         3  1261.50   Multiple Order
# 1       2025-09-23         4  1520.00   Multiple Order
# 2       2025-11-01         1  1020.75  Single Quantity
# 3       2025-10-28         5  3251.00   Multiple Order
# 4       2025-08-11         6  1772.40   Multiple Order

# %%
sales = pd.read_csv("sales.csv")

# %%
sales
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate  Quantity    Sales      Order Group
# 0       2025-10-15         3  1261.50   Multiple Order
# 1       2025-09-23         4  1520.00   Multiple Order
# 2       2025-11-01         1  1020.75  Single Quantity
# 3       2025-10-28         5  3251.00   Multiple Order
# 4       2025-08-11         6  1772.40   Multiple Order

# %% [markdown]
# ## Data Inspection

# %%
sales.shape
# Out:
# (5, 11)

# %%
## Find Data tyoes of each columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        5 non-null      int64
#  1   FirstName         5 non-null      object
#  2   LastName          5 non-null      object
#  3   Country           5 non-null      object
#  4   Gender            5 non-null      object
#  5   Age               5 non-null      int64
#  6   TotalPurchase     5 non-null      float64
#  7   LastPurchaseDate  5 non-null      object
#  8   Quantity          5 non-null      int64
#  9   Sales             5 non-null      float64
#  10  Order Group       5 non-null      object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 572.0+ bytes

# %%
# object -> str
sales.isna()
# Out:
#    CustomerID  FirstName  LastName  Country  Gender    Age  TotalPurchase  \
# 0       False      False     False    False   False  False          False
# 1       False      False     False    False   False  False          False
# 2       False      False     False    False   False  False          False
# 3       False      False     False    False   False  False          False
# 4       False      False     False    False   False  False          False
#
#    LastPurchaseDate  Quantity  Sales  Order Group
# 0             False     False  False        False
# 1             False     False  False        False
# 2             False     False  False        False
# 3             False     False  False        False
# 4             False     False  False        False

# %%
sales.isna().sum()
# Out:
# CustomerID          0
# FirstName           0
# LastName            0
# Country             0
# Gender              0
# Age                 0
# TotalPurchase       0
# LastPurchaseDate    0
# Quantity            0
# Sales               0
# Order Group         0
# dtype: int64

# %%
## Find duplicates
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# Count the number of duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.iloc[-1] = [5, "Samuel", "John", "Nigeria", "Male", 25, 420.50, '2025-10-15']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df.iloc[-1] = [5, "Samuel", "John", "Nigeria", "Male", 25, 420.50, '2025-10-15']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:1943, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1940 # align and set the values
#    1941 if take_split_path:
# ...

# %%
import numpy as np

# %%
df.iloc[-1] = [5, "Samuel", "John", "Nigeria", "Male", 25, np.nan, '2025-10-15']

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel     John  Nigeria    Male   25            NaN
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28
# 4       2025-10-15

# %%
## To remove null: na
df.dropna(axis=0)  # axis=0 : rows, axis=1, column
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel     John  Nigeria    Male   25            NaN
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28
# 4       2025-10-15

# %%
## To remove null: na
df = df.dropna(axis=0)  # axis=0 : rows, axis=1, column

# %%
## To remove null: na
df.dropna(axis=0, inplace=True)  # axis=0 : rows, axis=1, column
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6828\289449091.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0, inplace=True)  # axis=0 : rows, axis=1, column

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6828\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28

# %%
## Sunmary statistics: mean, median, maximum, minimum, 25%, 50%, 75%

df.describe()
# Out:
#        CustomerID       Age  TotalPurchase
# count    4.000000   4.00000        4.00000
# mean     2.500000  33.75000      617.86250
# std      1.290994   5.85235      293.76554
# min      1.000000  27.00000      380.00000
# 25%      1.750000  30.75000      410.37500
# 50%      2.500000  33.50000      535.35000
# 75%      3.250000  36.50000      742.83750
# max      4.000000  41.00000     1020.75000

# %%
df.describe(include="object")
# Out:
#        FirstName LastName  Country Gender LastPurchaseDate
# count          4        4        4      4                4
# unique         4        4        3      2                4
# top        James    Okoro  Nigeria   Male       2025-10-15
# freq           1        1        2      2                1

# %%
df.describe(exclude=[np.number])
# Out:
#        FirstName LastName  Country Gender LastPurchaseDate
# count          4        4        4      4                4
# unique         4        4        3      2                4
# top        James    Okoro  Nigeria   Male       2025-10-15
# freq           1        1        2      2                1

# %% [markdown]
# ### Column

# %%
df.FirstName
# Out:
# 0    James
# 1      Ada
# 2     John
# 3     Mary
# Name: FirstName, dtype: object

# %%
df['FirstName'] # -> Series
# Out:
# 0    James
# 1      Ada
# 2     John
# 3     Mary
# Name: FirstName, dtype: object

# %%
df[['FirstName', 'LastName']] # -> DataFrame
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh
# 2      John      Doe
# 3      Mary  Adeyemi

# %%
df[['FirstName', 'LastName', 'Age']]
# Out:
#   FirstName LastName  Age
# 0     James    Okoro   32
# 1       Ada     Umeh   27
# 2      John      Doe   41
# 3      Mary  Adeyemi   35

# %%
# loc, iloc
# df.loc[row, col]

df.loc[0:2, ["FirstName", "LastName"]]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh
# 2      John      Doe

# %%
df.loc[0:2, :]
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01

# %%
df.iloc[0:2, [1, 2]]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh

# %%
df.iloc[0:2, 1:3]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh

# %%
df.iloc[0:3, 1:3]
# Out:
#   FirstName LastName
# 0     James    Okoro
# 1       Ada     Umeh
# 2      John      Doe

# %% [markdown]
# ### Data Filtering

# %%
import pandas as pd

# %%
df = pd.read_json("sales.json")

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate
# 0       2025-10-15
# 1       2025-09-23
# 2       2025-11-01
# 3       2025-10-28
# 4       2025-08-11

# %%
## Converting a olumn into datetime

# %%
df['Quantity'] = [3, 4, 1, 5, 6]

# %%
df.head()
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate  Quantity
# 0       2025-10-15         3
# 1       2025-09-23         4
# 2       2025-11-01         1
# 3       2025-10-28         5
# 4       2025-08-11         6

# %%
df['Sales'] = df['TotalPurchase'] * df['Quantity']

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate  Quantity    Sales
# 0       2025-10-15         3  1261.50
# 1       2025-09-23         4  1520.00
# 2       2025-11-01         1  1020.75
# 3       2025-10-28         5  3251.00
# 4       2025-08-11         6  1772.40

# %%
import numpy as np

# %%
df['Order Group'] = np.where(df['Quantity'] > 1, "Multiple Order", "Single Quantity")

# %%
df
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 1           2       Ada     Umeh    Ghana  Female   27         380.00
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
# 4           5    Samuel   Mutiso    Kenya    Male   29         295.40
#
#   LastPurchaseDate  Quantity    Sales      Order Group
# 0       2025-10-15         3  1261.50   Multiple Order
# 1       2025-09-23         4  1520.00   Multiple Order
# 2       2025-11-01         1  1020.75  Single Quantity
# 3       2025-10-28         5  3251.00   Multiple Order
# 4       2025-08-11         6  1772.40   Multiple Order

# %%
df['Age'] > 30
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Age, dtype: bool

# %%
df[df['Age'] > 30]
# Out:
#    CustomerID FirstName LastName  Country  Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria    Male   32         420.50
# 2           3      John      Doe    Kenya    Male   41        1020.75
# 3           4      Mary  Adeyemi  Nigeria  Female   35         650.20
#
#   LastPurchaseDate  Quantity    Sales      Order Group
# 0       2025-10-15         3  1261.50   Multiple Order
# 2       2025-11-01         1  1020.75  Single Quantity
# 3       2025-10-28         5  3251.00   Multiple Order

# %%
df['FirstName'] == "James"
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: FirstName, dtype: bool

# %%
df[df['FirstName'] == "James"]
# Out:
#    CustomerID FirstName LastName  Country Gender  Age  TotalPurchase  \
# 0           1     James    Okoro  Nigeria   Male   32          420.5
#
#   LastPurchaseDate  Quantity   Sales     Order Group
# 0       2025-10-15         3  1261.5  Multiple Order

# %%
## Filter out where the sales is between 1500 and 2000

(df['Sales'] > 1500) & (df['Sales'] <= 2000)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Sales, dtype: bool

# %%
## Filter out where the sales is between 1500 and 2000

df[(df['Sales'] >= 1500) & (df['Sales'] <= 2000)]
# Out:
#    CustomerID FirstName LastName Country  Gender  Age  TotalPurchase  \
# 1           2       Ada     Umeh   Ghana  Female   27          380.0
# 4           5    Samuel   Mutiso   Kenya    Male   29          295.4
#
#   LastPurchaseDate  Quantity   Sales     Order Group
# 1       2025-09-23         4  1520.0  Multiple Order
# 4       2025-08-11         6  1772.4  Multiple Order

# %%
df[df['Sales'].between(1500, 2000)]
# Out:
#    CustomerID FirstName LastName Country  Gender  Age  TotalPurchase  \
# 1           2       Ada     Umeh   Ghana  Female   27          380.0
# 4           5    Samuel   Mutiso   Kenya    Male   29          295.4
#
#   LastPurchaseDate  Quantity   Sales     Order Group
# 1       2025-09-23         4  1520.0  Multiple Order
# 4       2025-08-11         6  1772.4  Multiple Order

# %%
# find where quantity > 3 or firstname = John

# %%
import pandas as pd   

pd.ExcelFile("Creators_Stadio (2).xlsx").sheet_names
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[96], line 3
#       1 import pandas as pd
# ----> 3 pd.ExcelFile("Creators_Stadio (2).xlsx").sheet_names
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# ...

# %%
df = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
# ...

# %%
df.head()
# Out:
#         Date Customer Type                   Country  Product Discount Band  \
# 0 2022-12-01    Government                   Germany   MN1001           NaN
# 1 2022-12-01     Education  United States of America  FR10020           NaN
# 2 2022-12-01    Government                    Canada  FR10021           NaN
# 3 2022-12-01    Government                   Germany  FR10021           NaN
# 4 2022-12-01    Government                    Canada   MN1004           NaN
#
#    Units Sold
# 0      1513.0
# 1       615.0
# 2      1817.0
# 3      1513.0
# 4      1817.0

# %%
df
# Out:
#            Date Customer Type                   Country  Product  \
# 0    2022-12-01    Government                   Germany   MN1001
# 1    2022-12-01     Education  United States of America  FR10020
# 2    2022-12-01    Government                    Canada  FR10021
# 3    2022-12-01    Government                   Germany  FR10021
# 4    2022-12-01    Government                    Canada   MN1004
# ...         ...           ...                       ...      ...
# 1041 2021-01-01       Creator                    Canada   LO1200
# 1042 2021-01-01    Government                   Germany   MN1001
# 1043 2021-01-01     Education                   Germany  FR10022
# 1044 2021-01-01    Enterprise                    France   MN1001
# 1045 2021-01-01     Education                    Canada  FR10021
#
#      Discount Band  Units Sold
# 0              NaN      1513.0
# 1              NaN       615.0
# 2              NaN      1817.0
# 3              NaN      1513.0
# ...

# %%
df.to_csv("sales.csv", index=False)

# %%
df = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
df.to_csv("products.csv", index=False)

# %%
df.isnull()
df.notnull()
df.dropna()
df.fillna(0)
df["age"].fillna(df["age"].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd

# %%
product = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
sales = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 product = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
#       2 sales = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...

# %%
sales
# Out:
#            Date Customer Type                   Country  Product  \
# 0    2022-12-01    Government                   Germany   MN1001
# 1    2022-12-01     Education  United States of America  FR10020
# 2    2022-12-01    Government                    Canada  FR10021
# 3    2022-12-01    Government                   Germany  FR10021
# 4    2022-12-01    Government                    Canada   MN1004
# ...         ...           ...                       ...      ...
# 1041 2021-01-01       Creator                    Canada   LO1200
# 1042 2021-01-01    Government                   Germany   MN1001
# 1043 2021-01-01     Education                   Germany  FR10022
# 1044 2021-01-01    Enterprise                    France   MN1001
# 1045 2021-01-01     Education                    Canada  FR10021
#
#      Discount Band  Units Sold
# 0              NaN      1513.0
# 1              NaN       615.0
# 2              NaN      1817.0
# 3              NaN      1513.0
# ...

# %%
sales['Discount Band'].unique()
# Out:
# array([nan, 'Low', 'Medium', 'High'], dtype=object)

# %%
import numpy as np

# %%
sales['Discount Band'].replace(np.nan, "Unknown")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount Band'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sales['Discount Band'].fillna("Unknown")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount Band'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sales['Discount Band'] = sales['Discount Band'].fillna("Unknown")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount Band'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sales['Discount Band'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount Band'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1046 non-null   datetime64[ns]
#  1   Customer Type  1046 non-null   object
#  2   Country        1046 non-null   object
#  3   Product        1046 non-null   object
#  4   Discount Band  1046 non-null   object
#  5   Units Sold     1046 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 49.2+ KB

# %%
sales['year'] = sales['Date'].dt.year

# %%
sales
# Out:
#            Date Customer Type                   Country  Product  \
# 0    2022-12-01    Government                   Germany   MN1001
# 1    2022-12-01     Education  United States of America  FR10020
# 2    2022-12-01    Government                    Canada  FR10021
# 3    2022-12-01    Government                   Germany  FR10021
# 4    2022-12-01    Government                    Canada   MN1004
# ...         ...           ...                       ...      ...
# 1041 2021-01-01       Creator                    Canada   LO1200
# 1042 2021-01-01    Government                   Germany   MN1001
# 1043 2021-01-01     Education                   Germany  FR10022
# 1044 2021-01-01    Enterprise                    France   MN1001
# 1045 2021-01-01     Education                    Canada  FR10021
#
#      Discount Band  Units Sold  year
# 0          Unknown      1513.0  2022
# 1          Unknown       615.0  2022
# 2          Unknown      1817.0  2022
# ...

# %%
sales['month_name'] = sales['Date'].dt.month_name()

# %%
sales
# Out:
#            Date Customer Type                   Country  Product  \
# 0    2022-12-01    Government                   Germany   MN1001
# 1    2022-12-01     Education  United States of America  FR10020
# 2    2022-12-01    Government                    Canada  FR10021
# 3    2022-12-01    Government                   Germany  FR10021
# 4    2022-12-01    Government                    Canada   MN1004
# ...         ...           ...                       ...      ...
# 1041 2021-01-01       Creator                    Canada   LO1200
# 1042 2021-01-01    Government                   Germany   MN1001
# 1043 2021-01-01     Education                   Germany  FR10022
# 1044 2021-01-01    Enterprise                    France   MN1001
# 1045 2021-01-01     Education                    Canada  FR10021
#
#      Discount Band  Units Sold  year month_name
# 0          Unknown      1513.0  2022   December
# 1          Unknown       615.0  2022   December
# ...

# %%
sales["Date"].apply(lambda x: "Q" + str(x.quarter))
# Out:
# 0       Q4
# 1       Q4
# 2       Q4
# 3       Q4
# 4       Q4
#         ..
# 1041    Q1
# 1042    Q1
# 1043    Q1
# 1044    Q1
# 1045    Q1
# Name: Date, Length: 1046, dtype: object

# %%
sales['Quarter'] = sales["Date"].apply(lambda x: "Q" + str(x.quarter))

# %%
sales
# Out:
#            Date Customer Type                   Country  Product  \
# 0    2022-12-01    Government                   Germany   MN1001
# 1    2022-12-01     Education  United States of America  FR10020
# 2    2022-12-01    Government                    Canada  FR10021
# 3    2022-12-01    Government                   Germany  FR10021
# 4    2022-12-01    Government                    Canada   MN1004
# ...         ...           ...                       ...      ...
# 1041 2021-01-01       Creator                    Canada   LO1200
# 1042 2021-01-01    Government                   Germany   MN1001
# 1043 2021-01-01     Education                   Germany  FR10022
# 1044 2021-01-01    Enterprise                    France   MN1001
# 1045 2021-01-01     Education                    Canada  FR10021
#
#      Discount Band  Units Sold  year month_name Quarter
# 0          Unknown      1513.0  2022   December      Q4
# 1          Unknown       615.0  2022   December      Q4
# ...

# %%
import matplotlib.pyplot as plt

# %%
sales['Country'].value_counts()
# Out:
# Country
# Germany                     210
# Mexico                      210
# France                      210
# Canada                      208
# United States of America    208
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().plot(kind="bar", color="pink")
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.xticks(rotation=15)
plt.title("Count of Countries")
plt.show()

# %%
import pandas as pd

# %%
product = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
sales = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 product = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
#       2 sales = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...

# %%
product.to_csv("Products.csv", index=False) 
sales.to_csv("Sales.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 product.to_csv("Products.csv", index=False)
#       2 sales.to_csv("Sales.csv", index=False)
#
# NameError: name 'product' is not defined

# %%
import pandas as pd

# %%
sales = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
sales.head()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sales = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Sales Report")
#       2 sales.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
sales['Discount Band'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sales['Discount Band'].unique()
#
# NameError: name 'sales' is not defined

# %%
import numpy as np

# %%
sales['Discount Band'].replace(np.nan, "No Discount", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sales['Discount Band'].replace(np.nan, "No Discount", inplace=True)
#
# NameError: name 'sales' is not defined

# %%
sales['Discount Band'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sales['Discount Band'].unique()
#
# NameError: name 'sales' is not defined

# %%
sales['Quarter'] = sales['Date'].apply(lambda x: "Q" + str(x.quarter))
sales.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sales['Quarter'] = sales['Date'].apply(lambda x: "Q" + str(x.quarter))
#       2 sales.head()
#
# NameError: name 'sales' is not defined

# %%
sales['Year'] = sales['Date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sales['Year'] = sales['Date'].dt.year
#
# NameError: name 'sales' is not defined

# %%
sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sales
#
# NameError: name 'sales' is not defined

# %%
product = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 product = pd.read_excel("Creators_Stadio (2).xlsx", sheet_name="Product details")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
product
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 product
#
# NameError: name 'product' is not defined

# %% [markdown]
# ## Join

# %%
pd.merge(product, sales, how="left", left_on="Product ID", right_on="Product")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pd.merge(product, sales, how="left", left_on="Product ID", right_on="Product")
#
# NameError: name 'product' is not defined

# %%
df_2022 =df[df["year"] == 2022]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(df.columns)
# Out:
# Index(['CustomerID', 'FirstName', 'LastName', 'Country', 'Gender', 'Age',
#        'TotalPurchase', 'LastPurchaseDate', 'Quantity', 'Sales',
#        'Order Group'],
#       dtype='object')

# %%
df['year'] = pd.to_datetime(df['date']).dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# ...
